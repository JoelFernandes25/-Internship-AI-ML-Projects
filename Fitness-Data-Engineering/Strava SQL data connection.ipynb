# %%
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#      ---------------------------------------- 45.0/45.0 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.1

# %%
data_folder = r"C:\Users\Joel\Downloads\Fitabase Data 4.12.16-5.12.16"
engine = create_engine('sqlite:///bellabeat.db')

# %%
username = "root"
password = "joelferns"
host = "localhost"
port = 3306
database = "bellabeat"

# %%
engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# %%
for filename in os.listdir(data_folder):
    if filename.endswith(".csv"):
        file_path = os.path.join(data_folder, filename)
        df = pd.read_csv(file_path)
        table_name = filename.replace(".csv", "").lower().replace("-", "_").replace(" ", "_")
        df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]
        df.to_sql(table_name, con=engine, if_exists='replace', index=False)
        print(f"✅ Uploaded {table_name} to MySQL")
# Out:
# ✅ Uploaded dailyactivity_merged to MySQL
# ✅ Uploaded dailycalories_merged to MySQL
# ✅ Uploaded dailyintensities_merged to MySQL
# ✅ Uploaded dailysteps_merged to MySQL
# ✅ Uploaded heartrate_seconds_merged to MySQL
# ✅ Uploaded hourlycalories_merged to MySQL
# ✅ Uploaded hourlyintensities_merged to MySQL
# ✅ Uploaded hourlysteps_merged to MySQL
# ✅ Uploaded minutecaloriesnarrow_merged to MySQL
# ✅ Uploaded minutecalorieswide_merged to MySQL
# ✅ Uploaded minuteintensitiesnarrow_merged to MySQL
# ✅ Uploaded minuteintensitieswide_merged to MySQL
# ✅ Uploaded minutemetsnarrow_merged to MySQL
# ✅ Uploaded minutesleep_merged to MySQL
# ✅ Uploaded minutestepsnarrow_merged to MySQL
# ✅ Uploaded minutestepswide_merged to MySQL
# ✅ Uploaded sleepday_merged to MySQL
# ✅ Uploaded weightloginfo_merged to MySQL
